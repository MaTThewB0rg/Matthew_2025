# %%
---
comments: true
layout: post
title: Interests
description: Intrests from N&TM
author: Matthew Borg
permalink: /_notebooks/PBLBlogs/2025-2-26-intrestsfromN&TM.ipynb/
categories: [PBL Classes]
---

# %% [markdown]
# This blog is about my time at the second N&TM and the intrests I got from others presentations

# %% [markdown]
# # Intrests
# While at the second N&TM, I was able to see other classes and other coder's work, and I was amazed. There was so much new stuff and things I found interesting, it was like being a little kid at a toy store.
